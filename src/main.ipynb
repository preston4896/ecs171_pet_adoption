# %%
from get_data_final import *
# Out:
# Isolation Forest:  960
# LOF: 902

# %%
from pca import *

# %%
fig1

# %%
fig2

# %%
from test_ANN_model import *
# Out:
# Using TensorFlow backend.
# Dependent (reject H0)
# Running RFECV...
# RFECV completed.
# Optimal number of features: 17
# Least Important features:  Index(['Color3', 'Health', 'Fee', 'VideoAmt'], dtype='object')
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Epoch 1/50
# 5517/5517 [==============================] - 1s 115us/step - loss: 1.4770 - accuracy: 0.2759
# Epoch 2/50
# 5517/5517 [==============================] - 0s 63us/step - loss: 1.4700 - accuracy: 0.2737
# Epoch 3/50
# 5517/5517 [==============================] - 0s 68us/step - loss: 1.4667 - accuracy: 0.2704
# Epoch 4/50
# 5517/5517 [==============================] - 0s 63us/step - loss: 1.4652 - accuracy: 0.2724
# Epoch 5/50
# 5517/5517 [==============================] - 0s 65us/step - loss: 1.4647 - accuracy: 0.2768
# Epoch 6/50
# 5517/5517 [==============================] - 0s 67us/step - loss: 1.4603 - accuracy: 0.2777
# Epoch 7/50
# ...

# %%
from pr_curve import *
# Out:
# Epoch 1/60
#  - 1s - loss: 1.4718 - accuracy: 0.2802
# Epoch 2/60
#  - 1s - loss: 1.4650 - accuracy: 0.2714
# Epoch 3/60
#  - 1s - loss: 1.4636 - accuracy: 0.2710
# Epoch 4/60
#  - 1s - loss: 1.4596 - accuracy: 0.2795
# Epoch 5/60
#  - 1s - loss: 1.4541 - accuracy: 0.2886
# Epoch 6/60
#  - 1s - loss: 1.4515 - accuracy: 0.2916
# Epoch 7/60
#  - 1s - loss: 1.4482 - accuracy: 0.2941
# Epoch 8/60
#  - 1s - loss: 1.4467 - accuracy: 0.2957
# Epoch 9/60
#  - 1s - loss: 1.4445 - accuracy: 0.2962
# Epoch 10/60
#  - 1s - loss: 1.4434 - accuracy: 0.3056
# Epoch 11/60
#  - 1s - loss: 1.4408 - accuracy: 0.3025
# Epoch 12/60
#  - 1s - loss: 1.4396 - accuracy: 0.3085
# Epoch 13/60
#  - 1s - loss: 1.4379 - accuracy: 0.3077
# Epoch 14/60
#  - 1s - loss: 1.4356 - accuracy: 0.3112
# Epoch 15/60
#  - 1s - loss: 1.4348 - accuracy: 0.3146
# Epoch 16/60
#  - 1s - loss: 1.4343 - accuracy: 0.3172
# Epoch 17/60
#  - 1s - loss: 1.4314 - accuracy: 0.3264
# Epoch 18/60
#  - 1s - loss: 1.4281 - accuracy: 0.3210
# ...

# %%
f
